# %%
# %%writefile hello2d.cu
# #include <stdio.h>
#
# // Kernel function where each thread prints its global 2D thread ID
# __global__ void helloWorldKernel()
# {
#     // Calculate the global 2D thread ID
#     int threadIdX = blockIdx.x * blockDim.x + threadIdx.x;  // Global thread ID in X
#     int threadIdY = blockIdx.y * blockDim.y + threadIdx.y;  // Global thread ID in Y
#
#     // Print "Hello World" along with the thread ID and block/thread indices
#     printf("Hello World from thread (%d, %d) in block (%d, %d)\n",
#            threadIdX, threadIdY, blockIdx.x, blockIdx.y);
# }
#
# int main()
# {
#     // Define the number of threads per block (in 2D) and number of blocks (in 2D)
#     dim3 threadsPerBlock(4, 4);  // 4x4 threads per block
#     dim3 numBlocks(3, 3);        // 3x3 blocks in the grid
#
#     // Launch the kernel with 'numBlocks' 2D blocks and 'threadsPerBlock' 2D threads per block
#     helloWorldKernel<<<numBlocks, threadsPerBlock>>>();
#
#     // Wait for all threads to complete and synchronize
#     cudaDeviceSynchronize();
#
#     return 0;
# }
# Out:
# Writing hello2d.cu

# %%
# !nvcc -o hello2d hello2d.cu

# %%
# !./hello2d
# Out:
# Hello World from thread (8, 0) in block (2, 0)
# Hello World from thread (9, 0) in block (2, 0)
# Hello World from thread (10, 0) in block (2, 0)
# Hello World from thread (11, 0) in block (2, 0)
# Hello World from thread (8, 1) in block (2, 0)
# Hello World from thread (9, 1) in block (2, 0)
# Hello World from thread (10, 1) in block (2, 0)
# Hello World from thread (11, 1) in block (2, 0)
# Hello World from thread (8, 2) in block (2, 0)
# Hello World from thread (9, 2) in block (2, 0)
# Hello World from thread (10, 2) in block (2, 0)
# Hello World from thread (11, 2) in block (2, 0)
# Hello World from thread (8, 3) in block (2, 0)
# Hello World from thread (9, 3) in block (2, 0)
# Hello World from thread (10, 3) in block (2, 0)
# Hello World from thread (11, 3) in block (2, 0)
# Hello World from thread (4, 8) in block (1, 2)
# Hello World from thread (5, 8) in block (1, 2)
# Hello World from thread (6, 8) in block (1, 2)
# Hello World from thread (7, 8) in block (1, 2)
# Hello World from thread (4, 9) in block (1, 2)
# Hello World from thread (5, 9) in block (1, 2)
# Hello World from thread (6, 9) in block (1, 2)
# Hello World from thread (7, 9) in block (1, 2)
# Hello World from thread (4, 10) in block (1, 2)
# Hello World from thread (5, 10) in block (1, 2)
# Hello World from thread (6, 10) in block (1, 2)
# Hello World from thread (7, 10) in block (1, 2)
# Hello World from thread (4, 11) in block (1, 2)
# Hello World from thread (5, 11) in block (1, 2)
# Hello World from thread (6, 11) in block (1, 2)
# Hello World from thread (7, 11) in block (1, 2)
# Hello World from thread (4, 4) in block (1, 1)
# Hello World from thread (5, 4) in block (1, 1)
# Hello World from thread (6, 4) in block (1, 1)
# Hello World from thread (7, 4) in block (1, 1)
# Hello World from thread (4, 5) in block (1, 1)
# Hello World from thread (5, 5) in block (1, 1)
# Hello World from thread (6, 5) in block (1, 1)
# Hello World from thread (7, 5) in block (1, 1)
# Hello World from thread (4, 6) in block (1, 1)
# Hello World from thread (5, 6) in block (1, 1)
# Hello World from thread (6, 6) in block (1, 1)
# Hello World from thread (7, 6) in block (1, 1)
# Hello World from thread (4, 7) in block (1, 1)
# Hello World from thread (5, 7) in block (1, 1)
# Hello World from thread (6, 7) in block (1, 1)
# Hello World from thread (7, 7) in block (1, 1)
# Hello World from thread (0, 4) in block (0, 1)
# Hello World from thread (1, 4) in block (0, 1)
# Hello World from thread (2, 4) in block (0, 1)
# Hello World from thread (3, 4) in block (0, 1)
# Hello World from thread (0, 5) in block (0, 1)
# Hello World from thread (1, 5) in block (0, 1)
# Hello World from thread (2, 5) in block (0, 1)
# Hello World from thread (3, 5) in block (0, 1)
# Hello World from thread (0, 6) in block (0, 1)
# Hello World from thread (1, 6) in block (0, 1)
# Hello World from thread (2, 6) in block (0, 1)
# Hello World from thread (3, 6) in block (0, 1)
# Hello World from thread (0, 7) in block (0, 1)
# Hello World from thread (1, 7) in block (0, 1)
# Hello World from thread (2, 7) in block (0, 1)
# Hello World from thread (3, 7) in block (0, 1)
# Hello World from thread (8, 8) in block (2, 2)
# Hello World from thread (9, 8) in block (2, 2)
# Hello World from thread (10, 8) in block (2, 2)
# Hello World from thread (11, 8) in block (2, 2)
# Hello World from thread (8, 9) in block (2, 2)
# Hello World from thread (9, 9) in block (2, 2)
# Hello World from thread (10, 9) in block (2, 2)
# Hello World from thread (11, 9) in block (2, 2)
# Hello World from thread (8, 10) in block (2, 2)
# Hello World from thread (9, 10) in block (2, 2)
# Hello World from thread (10, 10) in block (2, 2)
# Hello World from thread (11, 10) in block (2, 2)
# Hello World from thread (8, 11) in block (2, 2)
# Hello World from thread (9, 11) in block (2, 2)
# Hello World from thread (10, 11) in block (2, 2)
# Hello World from thread (11, 11) in block (2, 2)
# Hello World from thread (0, 0) in block (0, 0)
# Hello World from thread (1, 0) in block (0, 0)
# Hello World from thread (2, 0) in block (0, 0)
# Hello World from thread (3, 0) in block (0, 0)
# Hello World from thread (0, 1) in block (0, 0)
# Hello World from thread (1, 1) in block (0, 0)
# Hello World from thread (2, 1) in block (0, 0)
# Hello World from thread (3, 1) in block (0, 0)
# Hello World from thread (0, 2) in block (0, 0)
# Hello World from thread (1, 2) in block (0, 0)
# Hello World from thread (2, 2) in block (0, 0)
# Hello World from thread (3, 2) in block (0, 0)
# Hello World from thread (0, 3) in block (0, 0)
# Hello World from thread (1, 3) in block (0, 0)
# Hello World from thread (2, 3) in block (0, 0)
# Hello World from thread (3, 3) in block (0, 0)
# Hello World from thread (8, 4) in block (2, 1)
# Hello World from thread (9, 4) in block (2, 1)
# Hello World from thread (10, 4) in block (2, 1)
# Hello World from thread (11, 4) in block (2, 1)
# Hello World from thread (8, 5) in block (2, 1)
# Hello World from thread (9, 5) in block (2, 1)
# Hello World from thread (10, 5) in block (2, 1)
# Hello World from thread (11, 5) in block (2, 1)
# Hello World from thread (8, 6) in block (2, 1)
# Hello World from thread (9, 6) in block (2, 1)
# Hello World from thread (10, 6) in block (2, 1)
# Hello World from thread (11, 6) in block (2, 1)
# Hello World from thread (8, 7) in block (2, 1)
# Hello World from thread (9, 7) in block (2, 1)
# Hello World from thread (10, 7) in block (2, 1)
# Hello World from thread (11, 7) in block (2, 1)
# Hello World from thread (4, 0) in block (1, 0)
# Hello World from thread (5, 0) in block (1, 0)
# Hello World from thread (6, 0) in block (1, 0)
# Hello World from thread (7, 0) in block (1, 0)
# Hello World from thread (4, 1) in block (1, 0)
# Hello World from thread (5, 1) in block (1, 0)
# Hello World from thread (6, 1) in block (1, 0)
# Hello World from thread (7, 1) in block (1, 0)
# Hello World from thread (4, 2) in block (1, 0)
# Hello World from thread (5, 2) in block (1, 0)
# Hello World from thread (6, 2) in block (1, 0)
# Hello World from thread (7, 2) in block (1, 0)
# Hello World from thread (4, 3) in block (1, 0)
# Hello World from thread (5, 3) in block (1, 0)
# Hello World from thread (6, 3) in block (1, 0)
# Hello World from thread (7, 3) in block (1, 0)
# Hello World from thread (0, 8) in block (0, 2)
# Hello World from thread (1, 8) in block (0, 2)
# Hello World from thread (2, 8) in block (0, 2)
# Hello World from thread (3, 8) in block (0, 2)
# Hello World from thread (0, 9) in block (0, 2)
# Hello World from thread (1, 9) in block (0, 2)
# Hello World from thread (2, 9) in block (0, 2)
# Hello World from thread (3, 9) in block (0, 2)
# Hello World from thread (0, 10) in block (0, 2)
# Hello World from thread (1, 10) in block (0, 2)
# Hello World from thread (2, 10) in block (0, 2)
# Hello World from thread (3, 10) in block (0, 2)
# Hello World from thread (0, 11) in block (0, 2)
# Hello World from thread (1, 11) in block (0, 2)
# Hello World from thread (2, 11) in block (0, 2)
# Hello World from thread (3, 11) in block (0, 2)
